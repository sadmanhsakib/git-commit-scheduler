# %%
import pandas as pd

df = pd.read_csv("storage/schedule.csv")
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   index           3 non-null      int64
#  1   commit_message  3 non-null      str
#  2   project_dir     3 non-null      str
#  3   commit_dir      3 non-null      str
#  4   backup_dir      0 non-null      float64
#  5   priority        3 non-null      int64
# dtypes: float64(1), int64(2), str(3)
# memory usage: 276.0 bytes
